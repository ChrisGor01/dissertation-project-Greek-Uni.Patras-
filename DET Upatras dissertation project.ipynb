# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sn
import openpyxl

# %%
fp=pd.read_excel(r"C:\Users\CG121\Documents\Πανεπιστήμιο Πατρών (ΔΕΤ)\Πτυχιακή Εργασία\Dissertation project (answers).xlsx", sheet_name= "preproc (2)")
pd.set_option("display.max_columns", None)
fp
# Out:
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0     Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4     Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..        ...        ...                     ...
# 136   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 137   Γυναίκα         24  Τριτοβάθμια εκπαίδευση
# 138    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 139   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 140    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                         Πελοπόννησος     Φοιτητής
# 1                                               Αττική     Φοιτητής
# 2                                        Δυτική Ελλάδα     Φοιτητής
# 3                                               Αττική     Φοιτητής
# ...

# %%
fp= fp.drop(fp[fp["2) Ηλικία"] < 18].index)
fp.reset_index(drop=True, inplace=True)
fp
# Out:
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0     Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4     Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..        ...        ...                     ...
# 129   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 130   Γυναίκα         24  Τριτοβάθμια εκπαίδευση
# 131    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 132   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 133    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                         Πελοπόννησος     Φοιτητής
# 1                                               Αττική     Φοιτητής
# 2                                        Δυτική Ελλάδα     Φοιτητής
# 3                                               Αττική     Φοιτητής
# ...

# %%
corr_matrix = fp.corr()
sn.heatmap(corr_matrix, annot=True)
plt.show()
# Out:
# C:\Users\CG121\AppData\Local\Temp\ipykernel_20080\2606932934.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = fp.corr()

# %%
x= fp["2) Ηλικία"]
y= fp["Προσανατολισμός στην Ευχαρίστηση"]
plt.scatter(x,y)
#Compute the coeficients from fitting x,y
z = np.polyfit(x, y, 1)
#Construct the polynomial
p = np.poly1d(z)
plt.plot(x, p(x), 'm-')
plt.xlabel("Age")
plt.ylabel("Pleasure")
plt.show()

# %%
#fp.to_excel(r"C:\Users\CG121\Documents\Πανεπιστήμιο Πατρών (ΔΕΤ)\Πτυχιακή Εργασία\Dissertation project (answers) 2.xlsx", sheet_name="preproc (3)", index=False)

# %%
fp2=pd.read_excel(r"C:\Users\CG121\Documents\Πανεπιστήμιο Πατρών (ΔΕΤ)\Πτυχιακή Εργασία\Dissertation project (answers).xlsx", 
                  sheet_name= "preproc (4)")
pd.set_option("display.max_columns", None)
fp2
# Out:
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0     Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4     Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..        ...        ...                     ...
# 101   Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 102   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 103    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 104   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 105    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                         Πελοπόννησος     Φοιτητής
# 1                                               Αττική     Φοιτητής
# 2                                        Δυτική Ελλάδα     Φοιτητής
# 3                                               Αττική     Φοιτητής
# ...

# %%
fp2["2) Ηλικία"].describe()
# Out:
# count    106.000000
# mean      24.094340
# std        7.627679
# min       18.000000
# 25%       20.000000
# 50%       22.000000
# 75%       23.750000
# max       51.000000
# Name: 2) Ηλικία, dtype: float64

# %%
x= fp2["2) Ηλικία"]
plt.boxplot(x)
plt.ylabel("Ηλικία")
plt.show()

# %%
fp2["1) Gender"].value_counts()
# Out:
# Γυναίκα    59
# Ανδρας     47
# Name: 1) Gender, dtype: int64

# %%
for col in fp2.columns:
     if col=="Φυσική Υγεία" and col== "Ψυχολογία" and col== "Κοινωνικές σχέσεις" and col== "Περιβάλλον" and col== "Φυσική Υγεία %" and col== "Ψυχολογία %" and col== "Κοινωνικές σχέσεις %" and col== "Περιβάλλον %":
            fp2r= round(fp2, 1)
fp2r
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 4
#       2      if col=="Φυσική Υγεία" and col== "Ψυχολογία" and col== "Κοινωνικές σχέσεις" and col== "Περιβάλλον" and col== "Φυσική Υγεία %" and col== "Ψυχολογία %" and col== "Κοινωνικές σχέσεις %" and col== "Περιβάλλον %":
#       3             fp2r= round(fp2, 1)
# ----> 4 fp2r
#
# NameError: name 'fp2r' is not defined

# %%
corr_matrix = fp2.corr()
sn.heatmap(corr_matrix, annot=True)
plt.show()
# Out:
# C:\Users\CG121\AppData\Local\Temp\ipykernel_12360\896196940.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr_matrix = fp2.corr()

# %%
pd.crosstab(index=fp2["1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;"], columns=fp2["1) Gender"])
# Out:
# 1) Gender                                     Ανδρας  Γυναίκα
# 1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;
# Όχι                                                5       23
# Ναι                                               42       36

# %%
pd.crosstab(index=fp2["3) Αθλείστε ;"], columns=fp2["1) Gender"])
# Out:
# 1) Gender      Ανδρας  Γυναίκα
# 3) Αθλείστε ;
# Όχι                 3       10
# Ναι                44       49

# %%
pd.crosstab(index=fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"], columns=fp2["1) Gender"])
# Out:
# 1) Gender                                           Ανδρας  Γυναίκα
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                     37       55
# Ναι                                                     10        4

# %%
pd.crosstab(index=fp2.iloc[:,16], columns=fp2["1) Gender"])
# Out:
# 1) Gender                                           Ανδρας  Γυναίκα
# 11) Παρακολουθείτε ηλεκτρονικό αθλητισμό (eSpor...
# Όχι                                                     20       50
# Ναι                                                     27        9

# %%
pd.crosstab(index=fp2["3) Αθλείστε ;"], columns=fp2["5) Εργασία"])
# Out:
# 5) Εργασία     Αλλο  Ανεργος  Δημόσιος Υπάλληλος  Ελεύθερος Επαγγελματίας  \
# 3) Αθλείστε ;
# Όχι               0        2                   0                        0
# Ναι               2        5                   2                        5
#
# 5) Εργασία     Ιδιωτικός Υπάλληλος  Φοιτητής
# 3) Αθλείστε ;
# Όχι                              4         7
# Ναι                              8        71

# %%
pd.crosstab(index=fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"], columns=fp2["5) Εργασία"])
# Out:
# 5) Εργασία                                          Αλλο  Ανεργος  \
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                    2        7
# Ναι                                                    0        0
#
# 5) Εργασία                                          Δημόσιος Υπάλληλος  \
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                                  2
# Ναι                                                                  0
#
# 5) Εργασία                                          Ελεύθερος Επαγγελματίας  \
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                                       5
# Ναι                                                                       0
#
# 5) Εργασία                                          Ιδιωτικός Υπάλληλος  \
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# ...

# %%
bins= [17,25,33,41,52]
fp2b= pd.cut(fp2["2) Ηλικία"], bins)
s = pd.cut(fp2["2) Ηλικία"], bins=bins).value_counts()
s
# Out:
# (17, 25]    85
# (25, 33]    10
# (41, 52]     8
# (33, 41]     3
# Name: 2) Ηλικία, dtype: int64

# %%
pd.crosstab(index=fp2["1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;"], columns=fp2b)
# Out:
# 2) Ηλικία                                     (17, 25]  (25, 33]  (33, 41]  \
# 1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;
# Όχι                                                 19         4         0
# Ναι                                                 66         6         3
#
# 2) Ηλικία                                     (41, 52]
# 1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;
# Όχι                                                  5
# Ναι                                                  3

# %%
pd.crosstab(index=fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"], columns=fp2b)
# Out:
# 2) Ηλικία                                           (17, 25]  (25, 33]  \
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                       72        10
# Ναι                                                       13         0
#
# 2) Ηλικία                                           (33, 41]  (41, 52]
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                        2         8
# Ναι                                                        1         0

# %%
pd.crosstab(index=fp2["6) Ετήσιο εισόδημα (σε ευρώ)"], columns=fp2b)
# Out:
# 2) Ηλικία                     (17, 25]  (25, 33]  (33, 41]  (41, 52]
# 6) Ετήσιο εισόδημα (σε ευρώ)
# 10.000-20.000                       13         4         1         4
# 21.000-30.000                        6         0         1         0
# 31.000+                              2         1         0         1
# 5.000-9.000                         64         5         1         3

# %%
pd.crosstab(index=fp2["1) Gender"], columns=fp2["2) Ποιο είναι το αγαπημένο σας άθλημα ;"])
# Out:
# 2) Ποιο είναι το αγαπημένο σας άθλημα ;  Kick box  Mountain bike  Muay Thai   \
# 1) Gender
# Ανδρας                                          0              1           1
# Γυναίκα                                         1              0           0
#
# 2) Ποιο είναι το αγαπημένο σας άθλημα ;  Ski  Αλπικο σκι  Βόλεϊ  \
# 1) Gender
# Ανδρας                                     1           1      1
# Γυναίκα                                    0           0     11
#
# 2) Ποιο είναι το αγαπημένο σας άθλημα ;  Γυμναστήριο - Bodybuilding/Powerlifting  \
# 1) Gender
# Ανδρας                                                                         0
# Γυναίκα                                                                        1
#
# 2) Ποιο είναι το αγαπημένο σας άθλημα ;  Κολύμβηση  Κολύμβηση   \
# 1) Gender
# Ανδρας                                           0           3
# Γυναίκα                                          1           0
#
# ...

# %%
avg_psych= fp2.groupby("1) Gender")["Ψυχολογία %"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Ποσοστό μέσης ψυχολογίας ανα φύλο")
plt.xlabel("Φύλο")
plt.ylabel("Ψυχολογία (%)")
plt.show()

# %%
male_nath_mean= fp2[fp2.iloc[:, 0] == "Ανδρας"].iloc[:, 32].mean()
female_nath_mean= fp2[fp2.iloc[:, 0] == "Γυναίκα"].iloc[:, 32].mean()
plt.bar(["Ανδρας", "Γυναίκα"], [male_nath_mean, female_nath_mean])
plt.title("Ποσοστό μέσης καλής φυσικής υγείας ανα φύλο")
plt.xlabel("Φύλο")
plt.ylabel("Φυσική Υγεία %")
plt.show()

# %% [markdown]
# # Παραδοσιακός Αθλητισμός και Θετική Ψυχολογία

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Προσανατολισμός στην Ευχαρίστηση"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο προσανατολισμού στην Ευχαρίστηση")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Ευχαρίστηση")
plt.show()

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Προσανατολισμός στη Δέσμευση"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο προσανατολισμού στη Δέσμευση")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Δέσμευση")
plt.show()

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Προσανατολισμός στο Νόημα"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο προσανατολισμoύ στο Νόημα")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Νόημα")
plt.show()

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Προσανατολισμός στη Νίκη"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο προσανατολισμού στη Νίκη")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Νίκη")
plt.show()

# %% [markdown]
# # Παραδοσιακός Αθλητισμός και Ποιότητα Ζωής

# %%
yes_nath_mean= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 32].mean()
no_nath_mean= fp2[fp2.iloc[:, 8] == "Όχι"].iloc[:, 32].mean()
plt.bar(["Όχι", "Ναι"], [no_nath_mean, yes_nath_mean])
plt.title("Μ.Ο Φυσικής Υγείας %")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Φυσική Υγεία %")
plt.show()

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Ψυχολογία %"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο Ψυχολογίας %")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Ψυχολογία %")
plt.show()

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Κοινωνικές σχέσεις %"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο Κοινωνικών σχέσεων %")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Κοινωνικές σχέσεις %")
plt.show()

# %%
avg_psych= fp2.groupby("3) Αθλείστε ;")["Περιβάλλον %"].mean()
plt.bar(avg_psych.index, avg_psych.values)
plt.title("Μ.Ο Περιβάλλοντος  %")
plt.xlabel("Αθλείστε ;")
plt.ylabel("Περιβάλλον %")
plt.show()

# %% [markdown]
# # Ηλεκτρονικός Αθλητισμός και Θετική Ψυχολογία

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Προσανατολισμός στην Ευχαρίστηση"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο προσανατολισμού στην Ευχαρίστηση")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Ευχαρίστηση")
plt.show()

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Προσανατολισμός στη Δέσμευση"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο προσανατολισμού στη Δέσμευση")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Δέσμευση")
plt.show()

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Προσανατολισμός στο Νόημα"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο προσανατολισμoύ στο Νόημα")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Νόημα")
plt.show()

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Προσανατολισμός στη Νίκη"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο προσανατολισμού στη Νίκη")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Νίκη")
plt.show()

# %% [markdown]
# # Ηλεκτρονικός Αθλητισμός και Ποιότητα Ζωής

# %%
yes_nath_mean= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 32].mean()
no_nath_mean= fp2[fp2.iloc[:, 18] == "Όχι"].iloc[:, 32].mean()
plt.bar(["Όχι", "Ναι"], [no_nath_mean, yes_nath_mean], color="green")
plt.title("Μ.Ο Φυσικής Υγείας %")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Φυσική Υγεία %")
plt.show()

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Ψυχολογία %"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο Ψυχολογίας %")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Ψυχολογία %")
plt.show()

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Κοινωνικές σχέσεις %"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο Κοινωνικών σχέσεων %")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Κοινωνικές σχέσεις %")
plt.show()

# %%
avg_psych= fp2.groupby("13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;")["Περιβάλλον %"].mean()
plt.bar(avg_psych.index, avg_psych.values, color="green")
plt.title("Μ.Ο Περιβάλλοντος  %")
plt.xlabel("Ασχολείστε με τα eSports ;")
plt.ylabel("Περιβάλλον %")
plt.show()

# %% [markdown]
# # Παραδοσιακός και Ηλ. Αθλητισμός (Θετική Ψυχολογία)

# %%
no_rows = fp2[(fp2["3) Αθλείστε ;"] == "Ναι") | (fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"] == "Ναι")]
no_rows
# Out:
# Γραμμές που περιέχουν 'Ναι' είτε στην στήλη '3) Αθλείστε ;' είτε στην '13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;':
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0     Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4     Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..        ...        ...                     ...
# 101   Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 102   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 103    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 104   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 105    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                         Πελοπόννησος     Φοιτητής
# 1                                               Αττική     Φοιτητής
# ...

# %%
no_rows2 = fp2[(fp2["3) Αθλείστε ;"] == "Ναι") & (fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"] == "Ναι")]
no_rows2
# Out:
# Γραμμές που περιέχουν 'Ναι' είτε στην στήλη '3) Αθλείστε ;' είτε στην '13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;':
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 6      Ανδρας         23  Τριτοβάθμια εκπαίδευση
# 9      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 11     Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 23     Ανδρας         20  Τριτοβάθμια εκπαίδευση
# 44     Ανδρας         20  Τριτοβάθμια εκπαίδευση
# 66     Ανδρας         20  Τριτοβάθμια εκπαίδευση
# 69     Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 80     Ανδρας         24  Τριτοβάθμια εκπαίδευση
# 81    Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 90     Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 92    Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 100   Γυναίκα         21  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 6                                         Πελοπόννησος     Φοιτητής
# ...

# %%
len(no_rows2)
# Out:
# 12

# %%
# Απο τους 95 η 12 είναι αυτοί που κάνουν και sports και esports
# Αρα 83 κάνουν είτε το ένα είτε το άλλο

# %%
no_rows3 = fp2[(fp2["3) Αθλείστε ;"] == "Όχι") & (fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"] == "Ναι")]
no_rows3
# Out:
#    1) Gender  2) Ηλικία             3) Εκπαίδευση  \
# 68    Ανδρας         36  Δευτεροβάθμια εκπαίδευση
# 83   Γυναίκα         18    Τριτοβάθμια εκπαίδευση
#
#    4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα;           5) Εργασία  \
# 68                                              Κρήτη    Ιδιωτικός Υπάλληλος
# 83                                       Πελοπόννησος               Φοιτητής
#
#    6) Ετήσιο εισόδημα (σε ευρώ) 1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;  \
# 68                  5.000-9.000                                          Ναι
# 83                  5.000-9.000                                          Ναι
#
#    2) Ποιο είναι το αγαπημένο σας άθλημα ; 3) Αθλείστε ;  \
# 68                              Ποδόσφαιρο           Όχι
# 83                              Ποδόσφαιρο           Όχι
#
#    4) Αν ναι πόσο συχνά ; 5) Αν αθλείστε, με ποιο άθλημα ασχολείστε ;   \
# 68                    NaN                                          NaN
# ...

# %%
# 2 είναι αυτοί που κάνουν μόνο eSports

# %%
no_rows4 = fp2[(fp2["3) Αθλείστε ;"] == "Ναι") & (fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"] == "Όχι")]
no_rows4
# Out:
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0     Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4     Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..        ...        ...                     ...
# 101   Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 102   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 103    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 104   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 105    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                         Πελοπόννησος     Φοιτητής
# 1                                               Αττική     Φοιτητής
# 2                                        Δυτική Ελλάδα     Φοιτητής
# 3                                               Αττική     Φοιτητής
# ...

# %%
# 81 είναι αυτοί που κάνουν μόνο sports

# %%
no_rows5 = fp2[(fp2["3) Αθλείστε ;"] == "Όχι") & (fp2["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"] == "Όχι")]
no_rows5
# Out:
#    1) Gender  2) Ηλικία             3) Εκπαίδευση  \
# 13   Γυναίκα         22    Τριτοβάθμια εκπαίδευση
# 24    Ανδρας         21    Τριτοβάθμια εκπαίδευση
# 27   Γυναίκα         47    Τριτοβάθμια εκπαίδευση
# 28   Γυναίκα         44  Δευτεροβάθμια εκπαίδευση
# 31   Γυναίκα         39  Δευτεροβάθμια εκπαίδευση
# 48   Γυναίκα         23    Τριτοβάθμια εκπαίδευση
# 54   Γυναίκα         42    Τριτοβάθμια εκπαίδευση
# 55   Γυναίκα         19    Τριτοβάθμια εκπαίδευση
# 65   Γυναίκα         19    Τριτοβάθμια εκπαίδευση
# 86   Γυναίκα         18  Δευτεροβάθμια εκπαίδευση
# 93    Ανδρας         24    Τριτοβάθμια εκπαίδευση
#
#    4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα;           5) Εργασία  \
# 13                                      Δυτική Ελλάδα               Φοιτητής
# 24                                             Αττική               Φοιτητής
# 27                                             Αττική                Ανεργος
# ...

# %%
len(no_rows5)
# Out:
# 11

# %%
# 11 είναι αυτοί που δεν κάνουν ούτε το ενα αλλά ούτε και το άλλο

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 24].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 24].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο προσανατολισμού στην Ευχαρίστηση ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Προσανατολισμός στην Ευχαρίστηση")
plt.show()

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 25].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 25].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο προσανατολισμού στη Δέσμευση ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Προσανατολισμός στην Δέσμευση")
plt.show()

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 26].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 26].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο προσανατολισμoύ στο Νόημα ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Προσανατολισμός στην Νόημα")
plt.show()

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 26].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 26].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο προσανατολισμού στη Νίκη ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Προσανατολισμός στην Νίκη")
plt.show()

# %% [markdown]
# # Παραδοσιακός και Ηλ. Αθλητισμός (Ποιότητα Ζωής)

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 32].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 32].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο Φυσικής Υγείας % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Φυσική Υγεία %")
plt.show()

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 33].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 33].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο Ψυχολογίας % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Ψυχολογία %")
plt.show()

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 34].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 34].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο Κοινωνικών Σχέσεων % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Κοινωνικές σχέσεις %")
plt.show()

# %%
yes_nath_mean_s= fp2[fp2.iloc[:, 8] == "Ναι"].iloc[:, 35].mean()
yes_nath_mean_es= fp2[fp2.iloc[:, 18] == "Ναι"].iloc[:, 35].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="red")
plt.title("Μ.Ο Περιβάλλοντος % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Περιβάλλον %")
plt.show()

# %% [markdown]
# # Ηλικίες 18 με 28

# %%
fp3=pd.read_excel(r"C:\Users\CG121\Documents\Πανεπιστήμιο Πατρών (ΔΕΤ)\Πτυχιακή Εργασία\Dissertation project (answers).xlsx", sheet_name= "preproc (4)")
fp3
# Out:
#     1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0     Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2      Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3      Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4     Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..        ...        ...                     ...
# 101   Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 102   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 103    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 104   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 105    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#     4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                         Πελοπόννησος     Φοιτητής
# 1                                               Αττική     Φοιτητής
# 2                                        Δυτική Ελλάδα     Φοιτητής
# 3                                               Αττική     Φοιτητής
# ...

# %%
fp3= fp3.drop(fp3[fp3["2) Ηλικία"] > 28].index)
fp3.reset_index(drop=True, inplace=True)
fp3
# Out:
#    1) Gender  2) Ηλικία           3) Εκπαίδευση  \
# 0    Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 1     Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 2     Ανδρας         22  Τριτοβάθμια εκπαίδευση
# 3     Ανδρας         21  Τριτοβάθμια εκπαίδευση
# 4    Γυναίκα         21  Τριτοβάθμια εκπαίδευση
# ..       ...        ...                     ...
# 84   Γυναίκα         22  Τριτοβάθμια εκπαίδευση
# 85   Γυναίκα         18  Τριτοβάθμια εκπαίδευση
# 86    Ανδρας         19  Τριτοβάθμια εκπαίδευση
# 87   Γυναίκα         19  Τριτοβάθμια εκπαίδευση
# 88    Ανδρας         22  Τριτοβάθμια εκπαίδευση
#
#    4) Σε ποια περιφέρεια της Ελλάδας κατοικείτε μόνιμα; 5) Εργασία  \
# 0                                        Πελοπόννησος     Φοιτητής
# 1                                              Αττική     Φοιτητής
# 2                                       Δυτική Ελλάδα     Φοιτητής
# 3                                              Αττική     Φοιτητής
# ...

# %%
fp3["1) Gender"].value_counts()
# Out:
# Γυναίκα    46
# Ανδρας     43
# Name: 1) Gender, dtype: int64

# %%
pd.crosstab(index=fp3["1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;"], columns=fp3["1) Gender"])
# Out:
# 1) Gender                                     Ανδρας  Γυναίκα
# 1) Ασχολείστε με τον παραδοσιακό αθλητισμό ;
# Όχι                                                5       16
# Ναι                                               38       30

# %%
pd.crosstab(index=fp3["3) Αθλείστε ;"], columns=fp3["1) Gender"])
# Out:
# 1) Gender      Ανδρας  Γυναίκα
# 3) Αθλείστε ;
# Όχι                 2        6
# Ναι                41       40

# %%
pd.crosstab(index=fp3.iloc[:,16], columns=fp3["1) Gender"])
# Out:
# 1) Gender                                           Ανδρας  Γυναίκα
# 11) Παρακολουθείτε ηλεκτρονικό αθλητισμό (eSpor...
# Όχι                                                     19       38
# Ναι                                                     24        8

# %%
pd.crosstab(index=fp3["13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγγελματικά (eSports) ;"], columns=fp3["1) Gender"])
# Out:
# 1) Gender                                           Ανδρας  Γυναίκα
# 13) Ασχολείστε με τα διαδικτυακά παιχνίδια επαγ...
# Όχι                                                     34       42
# Ναι                                                      9        4

# %%
yes_nath_mean_s= fp3[fp3.iloc[:, 8] == "Ναι"].iloc[:, 32].mean()
yes_nath_mean_es= fp3[fp3.iloc[:, 18] == "Ναι"].iloc[:, 32].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="orange")
plt.title("Μ.Ο Φυσικής Υγείας % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Φυσική Υγεία %")
plt.show()

# %%
yes_nath_mean_s= fp3[fp3.iloc[:, 8] == "Ναι"].iloc[:, 33].mean()
yes_nath_mean_es= fp3[fp3.iloc[:, 18] == "Ναι"].iloc[:, 33].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="orange")
plt.title("Μ.Ο Ψυχολογίας % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Ψυχολογία %")
plt.show()

# %%
yes_nath_mean_s= fp3[fp3.iloc[:, 8] == "Ναι"].iloc[:, 34].mean()
yes_nath_mean_es= fp3[fp3.iloc[:, 18] == "Ναι"].iloc[:, 34].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="orange")
plt.title("Μ.Ο Κοινωνικών Σχέσεων % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Κοινωνικές σχέσεις %")
plt.show()

# %%
yes_nath_mean_s= fp3[fp3.iloc[:, 8] == "Ναι"].iloc[:, 35].mean()
yes_nath_mean_es= fp3[fp3.iloc[:, 18] == "Ναι"].iloc[:, 35].mean()
plt.bar(["Sports", "eSports"], [yes_nath_mean_s, yes_nath_mean_es], color="orange")
plt.title("Μ.Ο Περιβάλλοντος % ανα κατηγορία αθλητισμού")
plt.xlabel("Με ποιό είδος αθλητισμού ασχολείστε ;")
plt.ylabel("Περιβάλλον %")
plt.show()
